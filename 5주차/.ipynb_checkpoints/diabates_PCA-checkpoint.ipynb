# %% [markdown]
# # PCA를 이용해서 diabates 적용

# %%
from sklearn.datasets import load_breast_cancer
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
import seaborn as sns

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras

df = pd.read_csv("C:/Users/Administrator/dataset/diabetes.csv", index_col=0)
df
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
# ...              ...            ...            ...      ...   ...
# 10               101             76             48      180  32.9
# 2                122             70             27        0  36.8
# 5                121             72             23      112  26.2
# 1                126             60              0        0  30.1
# 1                 93             70             31        0  30.4
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 6                               0.627   50        1
# ...

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten

# 1. 데이터 전처리 (표준화)
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# 2. PCA 적용 (주성분 2개로 축소)
pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled_data)

# 3. CNN 모델 정의
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(pca_data.shape[1], 1, 1)))
model.add(Flatten())
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 4. 모델 컴파일 및 학습
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(pca_data, labels, epochs=10, batch_size=32)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18344\2267358354.py in <module>
#      14 # 3. CNN 모델 정의
#      15 model = Sequential()
# ---> 16 model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(pca_data.shape[1], 1, 1)))
#      17 model.add(Flatten())
#      18 model.add(Dense(10, activation='relu'))
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\src\models\sequential.py in add(self, layer, rebuild)
#     119         self._layers.append(layer)
# ...
